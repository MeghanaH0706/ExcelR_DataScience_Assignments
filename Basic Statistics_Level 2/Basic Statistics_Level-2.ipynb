# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
X= pd.Series([24.23,25.53,25.41,24.14,29.62,28.25,25.81,24.39,40.26,32.95,91.36,25.99,39.42,26.71,35.00])

# %%
name=["Allied Signal","Bankers Trust","General Mills","ITT Industries","J.P.Morgan & Co.","Lehman Brothers","Marriott","MCI",
      "Merrill Lynch","Microsofy","Morgan Stanely","Sun Microsystems","Travelers","US Airways","Warner-Lambert"]

# %%
#pie chart
plt.figure(figsize=(5,7))
plt.pie(X,labels=name,autopct='%1.0f%%')
plt.show()

# %%
X.plot(kind="box",vert=False)
# Out:
# <AxesSubplot:>
